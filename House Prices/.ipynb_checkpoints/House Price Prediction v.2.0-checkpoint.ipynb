# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
import sklearn
plt.rcParams["figure.figsize"] = (18,9)
df = pd.read_csv('train.csv')
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
sns.heatmap(df.corr(),cmap='viridis', vmax=0.8, vmin=0)

# %%
cols = ['LotFrontage','OverallQual','']

# %%
cols = [ 'SalePrice',u'LotArea', u'YearBuilt', u'YearRemodAdd', u'MasVnrArea', u'BsmtFinSF1', u'BsmtUnfSF', u'TotalBsmtSF', u'1stFlrSF',u'GrLivArea',u'BsmtFullBath',u'FullBath',u'HalfBath', u'BedroomAbvGr', u'TotRmsAbvGrd', u'Fireplaces',u'GarageYrBlt', u'GarageCars', u'GarageArea', u'WoodDeckSF', u'OpenPorchSF', u'ScreenPorch', u'PoolArea', u'MoSold' ,u'3SsnPorch' ]

# %%
df_train = df[cols]
df_train.head(3)
# Out:
#    SalePrice  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0     208500     8450       2003          2003       196.0         706
# 1     181500     9600       1976          1976         0.0         978
# 2     223500    11250       2001          2002       162.0         486
#
#    BsmtUnfSF  TotalBsmtSF  1stFlrSF  GrLivArea    ...      Fireplaces  \
# 0        150          856       856       1710    ...               0
# 1        284         1262      1262       1262    ...               1
# 2        434          920       920       1786    ...               1
#
#    GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  ScreenPorch  \
# 0       2003.0           2         548           0           61            0
# 1       1976.0           2         460         298            0            0
# 2       2001.0           2         608           0           42            0
#
#    PoolArea  MoSold  3SsnPorch
# 0         0       2          0
# 1         0       5          0
# 2         0       9          0
#
# [3 rows x 25 columns]

# %%
df_train['MasVnrArea'].fillna(value=0 , inplace=True)

# %%
sns.heatmap(df_train.isnull())

# %%
df_train['GarageYrBlt'].mean()
# Out:
# 1978.5061638868744

# %%
df_train['GarageYrBlt'].fillna(value=1979 , inplace=True)

# %%
sns.heatmap(df_train.isnull())

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
X= df_train.drop('SalePrice' ,axis=1)
y= df_train['SalePrice']

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
rfr = RandomForestRegressor(n_estimators=100, max_depth=10, max_features=4)
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#            max_features=4, max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
print "Train Score {}".format(rfr.score(X_train,y_train))
print "Test Score {}".format(rfr.score(X_test,y_test))
# Out:
# Train Score 0.981422025305
# Test Score 0.794680084007
